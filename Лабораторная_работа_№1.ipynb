# %% [markdown]
# <a href="https://colab.research.google.com/github/Parygin13/My_First_Test_Repo/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%961.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Книга1.csv")

# %% [markdown]
# ## Пример использования What is Markdown?
# ### Нужно сделать:
#
# 1.   Список
# 2.   Рисунок
# 3.   Таблица
# 4.   Ссылка
#
# ![image.png](data:image/png;base64,...)
#
#
# ![iC7Y-7JMRao.jpg](data:image/jpeg;base64,...)
#
# [Ссылка на руководство по Mardown](https://https://colab.research.google.com/notebooks/intro.ipynb?hl=ru_RU&skip_cache=true%2Fspeech-to-text%2Fdocs%2Fsamples%2Fspeech-streaming-recognize)

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Книга1.csv")

# %% [markdown]
# **Текст, выделенный полужирным шрифтом**

# %% [markdown]
# # Новый раздел
